# %% [markdown]
# <a href="https://colab.research.google.com/github/ayomideolaniyan/Bank-Transaction/blob/main/Bank_Transaction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset

# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("electricsheepafrica/nigerian-banking-card-transactions")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# nigerian_card_transactions_full.parquet:   0%|          | 0.00/186M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3000000 [00:00<?, ? examples/s]

# %%
import pandas as pd

# Login using e.g. `huggingface-cli login` to access this dataset
df = pd.read_parquet("hf://datasets/electricsheepafrica/nigerian-banking-card-transactions/nigerian_card_transactions_full.parquet")

# %%
df
# Out:
#                                transaction_id        card_id  \
# 0        0b1de9b3-ae9f-4b1c-bbae-21b59dd275fe  CARD-00022541
# 1        4f12f52f-1f4b-4398-ac05-dac40ea1f53d  CARD-00000043
# 2        f6cb490a-fe96-4d80-8e75-dcc9d75abfe1  CARD-00037579
# 3        a1a38ecf-88ca-4269-b0e9-c9638bd0486f  CARD-00004030
# 4        ba702f5e-4b24-4dca-b78d-6e3705e10132  CARD-00001472
# ...                                       ...            ...
# 2999995  74407112-a3ef-4a16-aea9-85646f4e2090  CARD-00006587
# 2999996  597eae97-218c-4976-90b0-4722ac81c2a7  CARD-00011638
# 2999997  0c987026-d568-45b5-abc9-46316a031c7e  CARD-00007644
# 2999998  b5dde48d-2445-4634-a526-42b6f0a09bda  CARD-00000003
# 2999999  ef740443-1059-45bb-8925-a0194be4467c  CARD-00092440
#
#                   timestamp  amount_ngn  amount_usd currency  \
# 0       2023-07-23 20:31:00      7500.0         NaN      NGN
# 1       2023-07-02 09:21:00     38000.0         NaN      NGN
# ...

# %% [markdown]
# bank = df.read_to("Bank_trans.csv")

# %%
bank = df.to_csv("Bank_trans.csv")

# %%
import pandas as pd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 18 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   transaction_id          object
#  1   card_id                 object
#  2   timestamp               datetime64[ns]
#  3   amount_ngn              float64
#  4   amount_usd              float64
#  5   currency                object
#  6   merchant_category_code  object
#  7   pos_entry_mode          object
#  8   card_present            bool
#  9   cvv_provided            bool
#  10  avs_result              object
#  11  3ds_authenticated       bool
#  12  authorization_result    object
#  13  decline_reason          object
#  14  issuer_response_code    object
#  15  risk_score              float64
#  16  fraud_flag              bool
#  17  chargeback_flag         bool
# dtypes: bool(5), datetime64[ns](1), float64(3), object(9)
# memory usage: 311.9+ MB

# %%
df.describe()
# Out:
#                            timestamp    amount_ngn     amount_usd  \
# count                        3000000  3.000000e+06  239712.000000
# mean   2024-01-01 03:01:14.918319872  6.487230e+04      87.169880
# min              2023-01-01 00:06:00  1.000000e+02       0.133333
# 25%              2023-07-02 17:52:00  6.100000e+03       8.133333
# 50%              2023-12-31 20:50:00  1.800000e+04      24.000000
# 75%              2024-07-01 13:26:00  5.310000e+04      71.066667
# max              2024-12-30 23:59:00  1.000000e+07   13333.333333
# std                              NaN  2.046977e+05     275.029703
#
#          risk_score
# count  3.000000e+06
# mean   4.997972e+01
# min    6.642965e-05
# 25%    2.496764e+01
# 50%    4.994968e+01
# 75%    7.497420e+01
# max    1.000000e+02
# std    2.887511e+01

# %%
#To run a quick check on null values
df.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          3000000 non-null  object
#  1   card_id                 3000000 non-null  object
#  2   timestamp               3000000 non-null  datetime64[ns]
#  3   amount_ngn              3000000 non-null  float64
#  4   amount_usd              239712 non-null   float64
#  5   currency                3000000 non-null  object
#  6   merchant_category_code  3000000 non-null  object
#  7   pos_entry_mode          3000000 non-null  object
#  8   card_present            3000000 non-null  bool
#  9   cvv_provided            3000000 non-null  bool
#  10  avs_result              3000000 non-null  object
#  11  3ds_authenticated       3000000 non-null  bool
#  12  authorization_result    3000000 non-null  object
# ...
